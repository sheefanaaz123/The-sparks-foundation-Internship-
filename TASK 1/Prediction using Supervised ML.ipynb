# %% [markdown]
# # TASK 1 : PREDICTION USING SUPERVISED ML

# %% [markdown]
# #### The task is to predict the percentage of a student based on the number of study hours.
# #### We have used linear regression model for this task.

# %%
#importing libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing dataset

dataset = pd.read_csv("student_scores - student_scores.csv")

#printing first five rows of dataframe
print(dataset.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#plotting the hours and scores using matplotlib

dataset.plot(x='Hours', y='Scores', style='*')
plt.title("HOURS VS PERCENTAGE")
plt.xlabel('Hours studied by student')  
plt.ylabel('Percentage scored by student')  
plt.show()

# %% [markdown]
# #### From the graph above, we observe that there is a positive linear relation between the number of hours studied and percentage of score by student.

# %% [markdown]
# ### Preparing the data

# %%
#dividing the dataset into attributes and labels.
x = dataset.iloc[:, :-1].values  
y = dataset.iloc[:,-1].values

# %%
#Splitting the data into training and test sets.

from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Training the model

# %%
#training our model

from sklearn.linear_model import LinearRegression  
model = LinearRegression()  
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#plotting the regression line
line = model.coef_*x+model.intercept_

#plotting
plt.scatter(x, y)
plt.plot(x, line);
plt.show()

# %% [markdown]
# ### Prediction

# %%
y_pred = model.predict(x_test)

# %%
#Comparing Actual and Predicted percentage

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# ### What will be the predicted scores (percentage) if student studies for 9.25 hrs/day?

# %%
hours = [[9.25]]
own_pred = model.predict(hours)
print("No of Hours = {}".format(hours[0][0]))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# ### Evaluating the model

# %%
#We have chosen mean square error for evaluation

from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
